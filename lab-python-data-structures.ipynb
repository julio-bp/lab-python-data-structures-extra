# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise 1: Working with Lists

# %% [markdown]
# Imagine you are building a program for a teacher who wants to track the progress of their students throughout the semester. The teacher wants to input the grades of each student one by one, and get a summary of their performance. There are in total 5 students. You are tasked with building the program that will allow the teacher to do this easily.
#
# The program will prompt the teacher to enter the grades of each student. Once the teacher has entered all the grades, the program will calculate the total sum of the grades and display it on the screen. Then, the program will create a new list by selecting only the grades of the first, third, and fifth students entered by the teacher, and sort them in ascending order.
#
# Finally, the program will print out the new list, along with its length and the number of occurrences of the score 5 in the list. This will give the teacher a good overview of the performance of the selected students, and help them identify any potential issues early on.

# %% [markdown]
# *Hint:*
# - You can use the input() function to ask the user to enter their information.
# - Look for list methods to perform the tasks.
# - Remember, it is possible to get a part of the sequence using:
#
#     ```python
#     sequence[x:y:z]
#     ```
#     where x, y, z are integers.
#
#     The above returns a new sequence with the following characteristics:
#
#     - A sequence with the same type as the original (a slice of a list is a list, a slice of a tuple is a tuple, and a slice of a string is a string).
#     - A sequence with elements from `sequence [x]` to `sequence [y-1]` (does not include a sequence [y]). By skipping `z` elements each time, it can be omitted if ` z = 1`.

# %% [markdown]
# *Recommended External Resources:*
# - *[Python Lists](https://www.w3schools.com/python/python_lists.asp)*
# - *[Python List Methods](https://www.w3schools.com/python/python_ref_list.asp)*
# - *[Python Built-in Functions](https://docs.python.org/3/library/functions.html)*

# %%
students_grades = []
student1 = int(input("Enter first student grades: "))
students_grades.append(student1)
student2 = int(input("Enter second student grades: "))
students_grades.append(student2)
student3 = int(input("Enter third student grades: "))
students_grades.append(student3)
student4 = int(input("Enter fourth student grades: "))
students_grades.append(student4)
student5 = int(input("Enter fifth student grades: "))
students_grades.append(student5)
print(students_grades)
# Out:
# [3, 10, 8, 5, 4]

# %%
print(sum(students_grades))
# Out:
# 30

# %%
selected_students = sorted(students_grades[::2])
print(selected_students)
# Out:
# [3, 4, 8]

# %%
occurrences = students_grades.count(5)
print(f"This is the new list with first, third and fifth students grades: {selected_students}. Has a length of {len(selected_students)} and the score 5 has occurred {occurrences} times.")
# Out:
# This is the new list with first, third and fifth students grades: [3, 4, 8]. Has a length of 3 and the score 5 has occurred 1 times.

# %% [markdown]
# ## Exercise 2: Tuples

# %% [markdown]
# Imagine you're running a fruit stand and want to keep track of your inventory. Write a Python program that does the following:
#
# - Initializes a tuple with 5 different types of fruit.
# - Outputs the first and last elements of the tuple, so you can see the full range of fruits the store offers.
# - Replaces the second element of the tuple with a new fruit that the store has recently received, and prints the updated tuple so you can see the changes.
# - Concatenates a new tuple containing 2 additional fruits to the original tuple, so you can add them to the store inventory, and prints the resulting tuple to see the updated inventory.
# - Splits the resulting tuple into 2 tuples of 3 elements each (the first tuple contains the first 3 elements, and the second tuple contains the last 3 elements), so you can organize the inventory more effectively.
# - Combines the 2 tuples from the previous step with the original tuple into a new tuple, and prints the resulting tuple and its length, so you can see the final inventory after all the changes.

# %% [markdown]
# *Recommended External Resources: [Python Tuples Examples and Methods](https://www.w3schools.com/python/python_tuples.asp)*

# %%
fruit1 = input("Enter frist fruit: ")
fruit2 = input("Enter second fruit: ")
fruit3 = input("Enter third fruit: ")
fruit4 = input("Enter forth fruit: ")
fruit5 = input("Enter fifth fruit: ")

tuple1 = (fruit1, fruit2, fruit3, fruit4, fruit5)

print(f"First tuple has this fruits {tuple1}")
# Out:
# First tuple has this fruits ('banana', 'orange', 'watermelon', 'grape', 'apple')

# %%
len(tuple1)
# Out:
# 5

# %%
print(f" First fruit on the tuple is: {tuple1[0]}")
print(f" Last fruit on the tuple is: {tuple1[4]}")
# Out:
#  First fruit on the tuple is: banana
#  Last fruit on the tuple is: apple

# %%
#From here down, I've been doing the exercice knowing that tuples cannot be modified, concatenized without repeating elements. So maybe the exercice was wrong?

# %%
list_from_tuple1 = list(tuple1)

list_from_tuple1.remove("watermelon")

list_from_tuple1.insert(2, "pear")

tuple2 = tuple(list_from_tuple1)

print(f"This is the second tuple with these fruits: {tuple2}")
# Out:
# This is the second tuple with these fruits: ('banana', 'orange', 'pear', 'grape', 'apple')

# %%
fruit7 = input("Enter a new fruit: ")
fruit8 = input("Enter a new fruit: ")
tuple3 = (fruit1, fruit2, fruit3, fruit4, fruit5, fruit7, fruit8)


combined_tuples = tuple1 + tuple3
print(f"This is the updated tuple: {combined_tuples}")
len(combined_tuples)
# Out:
# This is the updated tuple: ('banana', 'orange', 'watermelon', 'grape', 'apple', 'banana', 'orange', 'watermelon', 'grape', 'apple', 'peach', 'melon')
# 12

# %%
split_tuple1 = combined_tuples[:3]
split_tuple2 = combined_tuples[-4:]

print(split_tuple1)
print(split_tuple2)
# Out:
# ('banana', 'orange', 'watermelon')
# ('grape', 'apple', 'peach', 'melon')

# %%
last_tuple = tuple1 + split_tuple1 + split_tuple2
print(last_tuple)
len(last_tuple)
# Out:
# ('banana', 'orange', 'watermelon', 'grape', 'apple', 'banana', 'orange', 'watermelon', 'grape', 'apple', 'peach', 'melon')
# 12

# %% [markdown]
# ## Exercise 3: Sets

# %% [markdown]
# Imagine you are a data analyst working for a literature museum. Your manager has given you two poems to analyze, and she wants you to write a Python program to extract useful information from them.
#
# Your program should:
#
# - Create two sets, one for each poem, containing all unique words in both poems (ignoring case and punctuation).
# - Print the number of unique words in each set.
# - Identify and print the unique words present in the first poem but not in the second one.
# - Identify and print the unique words present in the second poem but not in the first one.
# - Identify and print the unique words present in both poems and print it in alphabetical order.

# %% [markdown]
# *Recommended External Resources:*
# - *[Python Sets](https://www.w3schools.com/python/python_sets.asp)*
# - *[Python Set Methods](https://www.w3schools.com/python/python_ref_set.asp)*
# - *[Python String Methods](https://www.w3schools.com/python/python_ref_string.asp)*

# %%
poem = """Some say the world will end in fire,
Some say in ice.
From what I’ve tasted of desire
I hold with those who favor fire.
But if it had to perish twice,
I think I know enough of hate
To say that for destruction ice
Is also great
And would suffice."""

new_poem = """Some say life is but a dream,
Some say it's a test.
From what I've seen and what I deem,
I side with those who see it as a quest.

But if it had to end today,
I think I know enough of love,
To say that though it fades away,
It's still what we are made of."""

# %%
poem1 = poem.lower().replace("," , " ").replace(".", " ").replace("\n", " ").split()

print(poem1)
# Out:
# ['some', 'say', 'the', 'world', 'will', 'end', 'in', 'fire', 'some', 'say', 'in', 'ice', 'from', 'what', 'i’ve', 'tasted', 'of', 'desire', 'i', 'hold', 'with', 'those', 'who', 'favor', 'fire', 'but', 'if', 'it', 'had', 'to', 'perish', 'twice', 'i', 'think', 'i', 'know', 'enough', 'of', 'hate', 'to', 'say', 'that', 'for', 'destruction', 'ice', 'is', 'also', 'great', 'and', 'would', 'suffice']

# %%
import string
new_poem = new_poem.lower()

for char in string.punctuation:
    new_poem = new_poem.replace(char, " ")

new_poem2 = new_poem.split()
print(new_poem2)
# Out:
# ['some', 'say', 'life', 'is', 'but', 'a', 'dream', 'some', 'say', 'it', 's', 'a', 'test', 'from', 'what', 'i', 've', 'seen', 'and', 'what', 'i', 'deem', 'i', 'side', 'with', 'those', 'who', 'see', 'it', 'as', 'a', 'quest', 'but', 'if', 'it', 'had', 'to', 'end', 'today', 'i', 'think', 'i', 'know', 'enough', 'of', 'love', 'to', 'say', 'that', 'though', 'it', 'fades', 'away', 'it', 's', 'still', 'what', 'we', 'are', 'made', 'of']

# %%
poem1_set = set(poem1)
poem2_set = set(new_poem2)

print(poem1_set)
print(poem2_set)
# Out:
# {'perish', 'twice', 'what', 'suffice', 'in', 'end', 'i', 'if', 'that', 'tasted', 'fire', 'those', 'to', 'also', 'from', 'desire', 'had', 'great', 'hate', 'destruction', 'for', 'some', 'but', 'of', 'know', 'and', 'the', 'it', 'is', 'favor', 'enough', 'who', 'ice', 'hold', 'think', 'say', 'world', 'with', 'i’ve', 'would', 'will'}
# {'still', 'see', 'what', 'today', 'dream', 'test', 'end', 'i', 'if', 'that', 'fades', 'we', 'as', 'are', 'to', 've', 'those', 'from', 'had', 'away', 'a', 'life', 'made', 'deem', 'but', 'of', 'and', 'know', 'quest', 'it', 'is', 's', 'love', 'though', 'enough', 'side', 'who', 'think', 'say', 'seen', 'with', 'some'}

# %%
difference_poem1 = poem1_set - poem2_set
print(difference_poem1)
# Out:
# {'perish', 'suffice', 'twice', 'in', 'tasted', 'fire', 'also', 'desire', 'great', 'destruction', 'for', 'the', 'favor', 'ice', 'hold', 'hate', 'world', 'i’ve', 'would', 'will'}

# %%
difference_poem2 = poem2_set - poem1_set
print(difference_poem2)
# Out:
# {'still', 'see', 'today', 'dream', 'test', 'we', 'fades', 'as', 'are', 've', 'away', 'a', 'life', 'made', 'deem', 'quest', 's', 'love', 'though', 'side', 'seen'}

# %%
poems_intersection = poem1_set & poem2_set
poems_intersection_sorted = sorted(poems_intersection)
print(poems_intersection_sorted)
# Out:
# ['and', 'but', 'end', 'enough', 'from', 'had', 'i', 'if', 'is', 'it', 'know', 'of', 'say', 'some', 'that', 'think', 'those', 'to', 'what', 'who', 'with']

# %% [markdown]
# ## Exercise 4: Dictionaries

# %% [markdown]
# Consider the following dictionary of students with their scores in different subjects. One of the students, Bob, has complained about his score in Philosophy and, after reviewing it, the teacher has decided to update his score to 100. Write a Python program that updates Bob's score in Philosophy to 100 in the dictionary.

# %% [markdown]
# *Recommended External Resources: [Python Dictionary Examples and Methods](https://www.w3schools.com/python/python_dictionaries.asp)*

# %%
grades = {'Alice': {'Physics': 75, 'Math': 85, 'Chemistry': 60, 'Philosophy': 90}, 'Bob': {'Physics': 75, 'Math': 85, 'Chemistry': 60, 'Philosophy': 90}}

# %%
grades["Bob"]
# Out:
# {'Physics': 75, 'Math': 85, 'Chemistry': 60, 'Philosophy': 90}

# %%
grades["Bob"]["Philosophy"] = 100

# %%
grades["Bob"]
# Out:
# {'Physics': 75, 'Math': 85, 'Chemistry': 60, 'Philosophy': 100}

# %% [markdown]
# ## Bonus

# %% [markdown]
# 1. Below are the two lists. Write a Python program to convert them into a dictionary in a way that item from list1 is the key and item from list2 is the value.

# %% [markdown]
# *Hint: Use the zip() function. This function takes two or more iterables (like list, dict, string), aggregates them in a tuple, and returns it. Afterwards, you can use a function that turns a tuple into a dictionary.*

# %% [markdown]
# *Recommended External Resources: [Python Zip Function](https://www.w3schools.com/python/ref_func_zip.asp)*

# %%
keys = ['Physics', 'Math', 'Chemistry', 'Philosophy']
values = [75, 85, 60,90]

new_dict = dict(zip(keys, values))

print(new_dict)
# Out:
# {'Physics': 75, 'Math': 85, 'Chemistry': 60, 'Philosophy': 90}

# %% [markdown]
# 2. Get the subject with the minimum score from the previous dictionary.

# %% [markdown]
# *Hint: Use the built-in function min(). Read about the parameter key.*

# %% [markdown]
# *Recommended External Resources:*
# - *[Python Min Function Official Documentation](https://docs.python.org/3.8/library/functions.html#min)*
# - *[How to use key function in max and min in Python](https://medium.com/analytics-vidhya/how-to-use-key-function-in-max-and-min-in-python-1fdbd661c59c)*

# %%
min(new_dict)
# Out:
# 'Chemistry'
